# %%
import pandas as pd
import numpy as np

# for database connection
import pyodbc

from random import randint

import datetime

# %%
data = pd.read_csv('entropy_data.csv')

# %%
data.shape
# Out:
# (6, 29)

# %%
data.head(5)
# Out:
#                     Timestamp          Email address What is your gender?  \
# 0   2019/11/17 4:26:47 PM PST     navjanar@gmail.com                 Male
# 1   2019/11/17 4:29:44 PM PST                    NaN               Female
# 2   2019/11/17 4:30:57 PM PST        tmacelli@uw.edu                 Male
# 3  2019/11/18 10:24:28 AM PST  Kylemcnulty@gmail.com                 Male
# 4   2019/11/19 7:36:43 PM PST         kathylt@uw.edu               Female
#
#   What is your age? What is your highest level of education?  \
# 0             20-30                              High school
# 1             20-30                              High school
# 2             20-30                      2 or 4 Year College
# 3             20-30                      2 or 4 Year College
# 4              0-20                      2 or 4 Year College
#
#    What is the size of your household (enter the number of people living in your residence/home)?  \
# 0                                                  2
# 1                                                  2
# 2                                                 12
# 3                                                  3
# 4                                                  2
#
#   What is the name of the item you are storing?  \
# 0                                  water bottle
# 1                                       earring
# 2                                           pen
# 3                                        Remote
# 4                                      Retainer
#
#   What is the name of the house you are storing this item in? (i.e. My apartment, Family house, or it can be an informal name like Georgetown)  \
# 0                                             Boston
# 1                                       my apartment
# 2                                             landis
# 3                                               Home
# 4                                       My apartment
#
#   What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.)  \
# 0                                          bedroom 1
# 1                                            bedroom
# 2                                            bedroom
# 3                                        Living room
# 4                                           bathroom
#
#    Which quadrant of the room is this item placed in? (see the image above for reference). The arrow shows the direction you are facing when you enter the room.  \
# 0                                                  3
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  1
#
#                                                                                          ...                                                                                          \
# 0                                                                                        ...
# 1                                                                                        ...
# 2                                                                                        ...
# 3                                                                                        ...
# 4                                                                                        ...
#
#   What is the name of the house are you storing this item in? (i.e. My apartment, Family house, or it can be an informal name like Georgetown).1  \
# 0                                                NaN
# 1                                       my apartment
# 2                                                NaN
# 3                                                NaN
# 4                                       My apartment
#
#   What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.).2  \
# 0                                                NaN
# 1                                            bedroom
# 2                                                NaN
# 3                                                NaN
# 4                                Kitchen/Dining room
#
#   Which quadrant of the room is this item placed in? (see the image above for reference). The arrow shows the direction you are facing when you enter the room..2  \
# 0                                                NaN
# 1                                                2.0
# 2                                                NaN
# 3                                                NaN
# 4                                                3.0
#
#   If you would like to enter in a more personalized location description for this item, enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):.2  \
# 0                                                NaN
# 1                                   next to the desk
# 2                                                NaN
# 3                                                NaN
# 4                              On the kitchen island
#
#   Would you like to enter in another item?.2  \
# 0                                        NaN
# 1                                         No
# 2                                        NaN
# 3                                        NaN
# 4                                         No
#
#    What is the name of the item you are storing?.3  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   What is the name of the house are you storing this item in? (i.e. My apartment, Family house, or it can be an informal name like Georgetown).2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.).3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which quadrant of the room is this item placed in? (see the image above for reference). The arrow shows the direction you are facing when you enter the room..3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   If you would like to enter in a more personalized location description for this item, enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):.3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 29 columns]

# %%
"""time = Timestamp
email = Email address
gender = What is your gender?
age = What is your age?
edu = What is your highest level of education?
household_size = What is the size of your household (enter the number of people living in your residence/home)?

r1_item = What is the name of the item you are storing?
r1_name_of_house = What is the name of the house you are storing this item in? (i.e. My apartment, 
    Family house, or it can be an informal name like Georgetown)
r1_room = What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.)
r1_quad_of_room = Which quadrant of the room is this item placed in? (see the image above for reference). 
    The arrow shows the direction you are facing when you enter the room.
r1_loc_desc = If you would like to enter in a more personalized location description for this item, 
    enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):
    
r2_item = What is the name of the item you are storing?
r2_name_of_house = What is the name of the house you are storing this item in? (i.e. My apartment, 
    Family house, or it can be an informal name like Georgetown)
r2_room = What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.)
r2_quad_of_room = Which quadrant of the room is this item placed in? (see the image above for reference). 
    The arrow shows the direction you are facing when you enter the room.
r2_loc_desc = If you would like to enter in a more personalized location description for this item, 
    enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):

r3_item = What is the name of the item you are storing?
r3_name_of_house = What is the name of the house you are storing this item in? (i.e. My apartment, 
    Family house, or it can be an informal name like Georgetown)
r3_room = What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.)
r3_quad_of_room = Which quadrant of the room is this item placed in? (see the image above for reference). 
    The arrow shows the direction you are facing when you enter the room.
r3_loc_desc = If you would like to enter in a more personalized location description for this item, 
    enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):
    
r4_item = What is the name of the item you are storing?
r4_name_of_house = What is the name of the house you are storing this item in? (i.e. My apartment, 
    Family house, or it can be an informal name like Georgetown)
r4_room = What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.)
r4_quad_of_room = Which quadrant of the room is this item placed in? (see the image above for reference). 
    The arrow shows the direction you are facing when you enter the room.
r4_loc_desc = If you would like to enter in a more personalized location description for this item, 
    enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):
"""
# Out:
# 'time = Timestamp\nemail = Email address\ngender = What is your gender?\nage = What is your age?\nedu = What is your highest level of education?\nhousehold_size = What is the size of your household (enter the number of people living in your residence/home)?\n\nr1_item = What is the name of the item you are storing?\nr1_name_of_house = What is the name of the house you are storing this item in? (i.e. My apartment, \n    Family house, or it can be an informal name like Georgetown)\nr1_room = What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.)\nr1_quad_of_room = Which quadrant of the room is this item placed in? (see the image above for reference). \n    The arrow shows the direction you are facing when you enter the room.\nr1_loc_desc = If you would like to enter in a more personalized location description for this item, \n    enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):\n    \nr2_item = What is the name of the item you are storing?\nr2_name_of_house = What is the name of the house you are storing this item in? (i.e. My apartment, \n    Family house, or it can be an informal name like Georgetown)\nr2_room = What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.)\nr2_quad_of_room = Which quadrant of the room is this item placed in? (see the image above for reference). \n    The arrow shows the direction you are facing when you enter the room.\nr2_loc_desc = If you would like to enter in a more personalized location description for this item, \n    enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):\n\nr3_item = What is the name of the item you are storing?\nr3_name_of_house = What is the name of the house you are storing this item in? (i.e. My apartment, \n    Family house, or it can be an informal name like Georgetown)\nr3_room = What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.)\nr3_quad_of_room = Which quadrant of the room is this item placed in? (see the image above for reference). \n    The arrow shows the direction you are facing when you enter the room.\nr3_loc_desc = If you would like to enter in a more personalized location description for this item, \n    enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):\n    \nr4_item = What is the name of the item you are storing?\nr4_name_of_house = What is the name of the house you are storing this item in? (i.e. My apartment, \n    Family house, or it can be an informal name like Georgetown)\nr4_room = What room are you storing the item in? (i.e. bathroom, living room, bedroom 1, etc.)\nr4_quad_of_room = Which quadrant of the room is this item placed in? (see the image above for reference). \n    The arrow shows the direction you are facing when you enter the room.\nr4_loc_desc = If you would like to enter in a more personalized location description for this item, \n    enter that here (i.e. I left my book on the second shelf of my nightstand next to my bed):\n'

# %%
data.columns = ['time', 'email', 'gender', 'age', 'edu', 'household_size', 
                            'r1_item', 'r1_name_of_house', 'r1_room', 'r1_quad_of_room', 'r1_loc_desc', 
                'add_item2', 'r2_item', 'r2_name_of_house', 'r2_room', 'r2_quad_of_room', 'r2_loc_desc', 
                'add_item3', 'r3_item', 'r3_name_of_house', 'r3_room', 'r3_quad_of_room', 'r3_loc_desc', 
                'add_item4', 'r4_item', 'r4_name_of_house', 'r4_room', 'r4_quad_of_room', 'r4_loc_desc']

# %%
data.head(5)
# Out:
#                          time                  email  gender    age  \
# 0   2019/11/17 4:26:47 PM PST     navjanar@gmail.com    Male  20-30
# 1   2019/11/17 4:29:44 PM PST                    NaN  Female  20-30
# 2   2019/11/17 4:30:57 PM PST        tmacelli@uw.edu    Male  20-30
# 3  2019/11/18 10:24:28 AM PST  Kylemcnulty@gmail.com    Male  20-30
# 4   2019/11/19 7:36:43 PM PST         kathylt@uw.edu  Female   0-20
#
#                    edu  household_size       r1_item r1_name_of_house  \
# 0          High school               2  water bottle           Boston
# 1          High school               2       earring     my apartment
# 2  2 or 4 Year College              12           pen           landis
# 3  2 or 4 Year College               3        Remote             Home
# 4  2 or 4 Year College               2      Retainer     My apartment
#
#        r1_room  r1_quad_of_room     ...     r3_name_of_house  \
# 0    bedroom 1                3     ...                  NaN
# 1      bedroom                1     ...         my apartment
# 2      bedroom                3     ...                  NaN
# 3  Living room                3     ...                  NaN
# 4     bathroom                1     ...         My apartment
#
#                r3_room r3_quad_of_room            r3_loc_desc add_item4  \
# 0                  NaN             NaN                    NaN       NaN
# 1              bedroom             2.0       next to the desk        No
# 2                  NaN             NaN                    NaN       NaN
# 3                  NaN             NaN                    NaN       NaN
# 4  Kitchen/Dining room             3.0  On the kitchen island        No
#
#    r4_item r4_name_of_house r4_room r4_quad_of_room r4_loc_desc
# 0      NaN              NaN     NaN             NaN         NaN
# 1      NaN              NaN     NaN             NaN         NaN
# 2      NaN              NaN     NaN             NaN         NaN
# 3      NaN              NaN     NaN             NaN         NaN
# 4      NaN              NaN     NaN             NaN         NaN
#
# [5 rows x 29 columns]

# %%
# separate data per item data frames
df1 = data[['time', 'email', 'gender', 'age', 'edu', 'household_size', 'r1_item', 'r1_name_of_house', 
            'r1_room', 'r1_quad_of_room', 'r1_loc_desc']]

# %%
df2 = data[['time', 'email', 'gender', 'age', 'edu', 'household_size', 'r2_item', 'r2_name_of_house', 
            'r2_room', 'r2_quad_of_room', 'r2_loc_desc']]

# %%
df3 = data[['time', 'email', 'gender', 'age', 'edu', 'household_size', 'r3_item', 'r3_name_of_house', 
            'r3_room', 'r3_quad_of_room', 'r3_loc_desc']]

# %%
df4 = data[['time', 'email', 'gender', 'age', 'edu', 'household_size', 'r4_item', 'r4_name_of_house', 
            'r4_room', 'r4_quad_of_room', 'r4_loc_desc']]

# %%
#df1.shape (6, 11)
df1.columns  = ['time', 'email', 'gender', 'age', 'edu', 'household_size', 'item', 
                'name_of_house', 'room', 'quad_of_room', 'loc_desc']

# %%
#df2.shape (6, 11)
df2.columns  = ['time', 'email', 'gender', 'age', 'edu', 'household_size', 'item', 
                'name_of_house', 'room', 'quad_of_room', 'loc_desc']

# %%
#df3.shape (6, 11)
df3.columns  = ['time', 'email', 'gender', 'age', 'edu', 'household_size', 'item', 
                'name_of_house', 'room', 'quad_of_room', 'loc_desc']

# %%
#df4.shape (6, 11)
df4.columns  = ['time', 'email', 'gender', 'age', 'edu', 'household_size', 'item', 
                'name_of_house', 'room', 'quad_of_room', 'loc_desc']

# %%
# combine all data into one dataframe with each item on its own row
df = df1.append(df2, ignore_index='true')
df = df.append(df3, ignore_index='true')
df = df.append(df4, ignore_index='true')

# %%
df.shape
# Out:
# (24, 11)

# %%
# DROP INCORRECT DATA

# %%
# remove any rows with no item data
df_real = df.dropna(subset=['item']).reset_index(drop=True)

# %%
df_real
# Out:
#                           time                  email  gender    age  \
# 0    2019/11/17 4:26:47 PM PST     navjanar@gmail.com    Male  20-30
# 1    2019/11/17 4:29:44 PM PST                    NaN  Female  20-30
# 2    2019/11/17 4:30:57 PM PST        tmacelli@uw.edu    Male  20-30
# 3   2019/11/18 10:24:28 AM PST  Kylemcnulty@gmail.com    Male  20-30
# 4    2019/11/19 7:36:43 PM PST         kathylt@uw.edu  Female   0-20
# 5    2019/11/22 1:20:45 PM PST        navjanar@uw.edu    Male  20-30
# 6    2019/11/17 4:26:47 PM PST     navjanar@gmail.com    Male  20-30
# 7    2019/11/17 4:29:44 PM PST                    NaN  Female  20-30
# 8    2019/11/17 4:30:57 PM PST        tmacelli@uw.edu    Male  20-30
# 9    2019/11/19 7:36:43 PM PST         kathylt@uw.edu  Female   0-20
# 10   2019/11/22 1:20:45 PM PST        navjanar@uw.edu    Male  20-30
# 11   2019/11/17 4:29:44 PM PST                    NaN  Female  20-30
# 12   2019/11/19 7:36:43 PM PST         kathylt@uw.edu  Female   0-20
# 13   2019/11/22 1:20:45 PM PST        navjanar@uw.edu    Male  20-30
# 14   2019/11/22 1:20:45 PM PST        navjanar@uw.edu    Male  20-30
#
#                     edu  household_size             item name_of_house  \
# 0           High school               2     water bottle        Boston
# 1           High school               2          earring  my apartment
# 2   2 or 4 Year College              12              pen        landis
# 3   2 or 4 Year College               3           Remote          Home
# 4   2 or 4 Year College               2         Retainer  My apartment
# 5           High school               4            phone      tristate
# 6           High school               2          blanket        Boston
# 7           High school               2              bed  my apartment
# 8   2 or 4 Year College              12          AI Book        Landis
# 9   2 or 4 Year College               2  Reading glasses  My apartment
# 10          High school               4          earbuds      tristate
# 11          High school               2   vacuum cleaner  my apartment
# 12  2 or 4 Year College               2       headphones  My apartment
# 13          High school               4       disney pen      tristate
# 14          High school               4       calculator      tristate
#
#                    room  quad_of_room                         loc_desc
# 0             bedroom 1           3.0                              NaN
# 1               bedroom           1.0                     On my drawer
# 2               bedroom           3.0     The pen is laying on my desk
# 3           Living room           3.0                              NaN
# 4              bathroom           1.0    On the shelf next to the sink
# 5             bedroom 1           2.0                              NaN
# 6             bedroom 1           3.0                              NaN
# 7               bedroom           4.0                              NaN
# 8               bedroom           4.0                   Next to my bed
# 9               bedroom           2.0  On my nightstand next to my bed
# 10            bedroom 3           4.0                              NaN
# 11              bedroom           2.0                 next to the desk
# 12  Kitchen/Dining room           3.0            On the kitchen island
# 13            bedroom 1           4.0                              NaN
# 14            bedroom 1           1.0                   drawer on desk

# %%
# PUTTING DATA INTO THE DB:

# %%
# Connect to our database, and return our database connection
def connectToDB():
    print("Connecting to database")
    mydb = pyodbc.connect(
        'DRIVER={ODBC Driver 13 for SQL Server};SERVER=is-info430.ischool.uw.edu;DATABASE=Group3-Final;UID=INFO430;PWD=wubalubadubdub'
    )
    print("Done connecting")
    return mydb

# %%
# insert into floor
insertFloor = """
SET NOCOUNT ON; 
EXECUTE [Group3-Final].dbo.[insert_Floor]
@Name = ?, 
@HouseName = ?
"""

## missing floor name from the forms, generating random floor

# %%
# insert into house
insertHouse = """
SET NOCOUNT ON; 
EXECUTE [Group3-Final].dbo.[insert_House]
@Name = ?, 
@Description = ?
"""

## missing house description from the forms

# %%
# insert into house group
insertHouseGroup = """
SET NOCOUNT ON; 
EXECUTE [Group3-Final].dbo.[insert_HouseGroup]
@Name = ?, 
@FirstName = ?,
@LastName = ?,
@Email = ?, 
@HouseName = ?, 
@HouseDescription = ?
"""

## missing house description from the forms
## what is name??

# %%
# insert item
insertItem = """
SET NOCOUNT ON; 
EXECUTE [Group3-Final].dbo.[insert_Item]
@ItemName = ?, 
@ImgSrc = ?,
@LocationDescription = ?,
@Condition = ?, 
@PurchaseDate = ?, 
@ExpirationDate = ?, 
@QuadrantName = ?, 
@ItemTypeName = ?
"""

## missing condition, purchase date, expiration date, and item type name from forms

# %%
# insert item type
insertItemType = """
SET NOCOUNT ON; 
EXECUTE [Group3-Final].dbo.[insert_ItemType]
@Name = ?, 
@Description = ?
"""

## missing item description from forms

# %%
# insert quadrant
insertQuadrant = """
SET NOCOUNT ON; 
EXECUTE [Group3-Final].dbo.[insert_Quadrant]
@Name = ?, 
@RoomName = ?
"""

# %%
# insert room
insertRoom = """
SET NOCOUNT ON; 
EXECUTE [Group3-Final].dbo.[insert_Room]
@Name = ?, 
@FloorName = ?, 
@HouseName = ?,
@RoomTypeName = ?
"""

## missing room descrptions from forms

# %%
# insert room type
insertRoomType = """
SET NOCOUNT ON;
EXECUTE [Group3-Final].dbo.[insert_RoomType]
@Name = ?, 
@Description = ?
"""

## missing room type descriptions

# %%
# insert user
insertUser = """
SET NOCOUNT ON;
EXECUTE [Group3-Final].dbo.[insert_User]
@FirstName = ?,
@LastName = ?,
@Email = ?,
@PassHash = ?
"""

# %%
# open db connection
cursor = connectToDB();
c = cursor.cursor()
# Out:
# Connecting to database
# Done connecting

# %%
# test for checking house exists in the database
#name_of_house = "Boston"
#c.execute("SELECT COUNT(*) FROM tblHouse WHERE HouseName = '" + name_of_house + "'")
#house_count = int(str(c.fetchall())[2:3])

# %%
for index, item in df_real.iterrows():
    # get necessary data and put into the the tables
    
    
    time = df_real['item'][index]
    
    # USER DATA:
    # need first name, need to update
    first_name = "fname" + str(index)
    
    # need last name, need to update
    last_name = "lname" + str(index)
    
    email = df_real['email'][index]
    if pd.isnull(email):
        email = "none" + str(index)
        
    # passw is replacing PassHash, need to update
    passw = "password" + str(index) 
    
    
    # ITEM INFORMATION:
    item = df_real['item'][index]
    
    # need to update item type to real item type not just name of item
    item_type = item + str(index)
    
    # need to update blank item description
    item_desc = ""
    
    # item img src is empty for now
    item_img_src = ""
    
    # blank condition description (not null)
    condition = "Good"
    
    # dummy purchase date & expiration date, need to update based on user input
    purchase = datetime.datetime(2019, 12, 2)
    expiration = datetime.datetime(2020, 12, 3)
    
    
    # HOUSE STORAGE INFORMATION:
    name_of_house = df_real['name_of_house'][index]
    
    # need to update home desc:
    home_desc = "Desc" + str(index)
    
    room = df_real['room'][index]
    
    # need to change this to room type when we get that data, for now same as room
    room_type = room + str(index)
    
    # room type desc blank for now, update later
    room_type_desc = ""
    
    quad_of_room = str(df_real['quad_of_room'][index])
    
    loc_desc = df_real['loc_desc'][index]
    if pd.isnull(loc_desc):
        loc_desc = ""
    
    # random floor number
    floor = str(randint(0, 3))
    
    
    # OTHER INFO (not necessary for database)
    gender = df_real['gender'][index]
    age = df_real['age'][index]
    edu = df_real['edu'][index]
    household_size = df_real['household_size'][index]
    
    
    # INSERT PARAMS CREATION
    insert_floor_params = (floor, name_of_house)
    insert_house_params = (name_of_house, home_desc)
    insert_user_params = (first_name, last_name, email, passw)
    insert_item_type_params = (item_type, item_desc)
    insert_room_type_params = (room_type, room_type_desc)
    insert_room_params = (room, floor, name_of_house, room_type)
    insert_quad_params = (quad_of_room, room)
    insert_item_params = (item, item_img_src, loc_desc, condition, purchase, expiration, quad_of_room, item_type)
    
    # need to update "what name" after figuring out what name this is
    insert_house_grp_params = ("what name", email, email, email, name_of_house, "")
    
    
    # EXECUTE INSERTS (WORKING)
    
    # execure insert house
    c.execute("SELECT COUNT(*) FROM tblHouse WHERE HouseName = '" + name_of_house + "'")
    house_count = int(str(c.fetchall())[2:3])
    if (house_count == 0):
        cursor.execute(insertHouse, insert_house_params)
        
    # execute insert floor
    c.execute("SELECT HouseID FROM tblHouse WHERE HouseName = '" + name_of_house + "'")
    house_id = str(c.fetchall())[2:3]

    c.execute("SELECT COUNT(*) FROM tblFloor WHERE FloorName = '" + floor + "' AND HouseID = '" + house_id + "'")
    floor_count = int(str(c.fetchall())[2:3])
    if (floor_count == 0):
        cursor.execute(insertFloor, insert_floor_params)
        
    cursor.execute(insertUser, insert_user_params)
    cursor.execute(insertItemType, insert_item_type_params)
    cursor.execute(insertRoomType, insert_room_type_params)
    
    
    # ERROR ONES:
    
    c.execute("SELECT FloorID FROM tblFloor WHERE FloorName = '" + floor + "'")
    floor_id = str(c.fetchall())[2:3]

    c.execute("SELECT COUNT(*) FROM tblRoom WHERE RoomName = '" + room + "' AND FloorID = '" + floor_id + "'")
    room_count = int(str(c.fetchall())[2:3])
    if (room_count == 0):
        cursor.execute(insertRoom, insert_room_params)
        
    # error with this one, below is error message:
    # Error: ('21000', '[21000] [Microsoft][ODBC Driver 13 for SQL Server][SQL Server]
    # Subquery returned more than 1 value. This is not permitted when the subquery 
    # follows =, !=, <, <= , >, >= or when the subquery is used as an expression. (512) (SQLExecDirectW)') 
    
    # need room first
    cursor.execute(insertQuadrant, insert_quad_params)
    
    
    
    # integrity error with nulls:
    # IntegrityError: ('23000', "[23000] [Microsoft][ODBC Driver 13 for SQL Server]
    # [SQL Server]Cannot insert the value NULL into column 'RoomID', table 
    # 'Group3-Final.dbo.tblQuadrant'; column does not allow nulls. INSERT fails. (515) (SQLExecDirectW)")
    
    # need quadrant first
    cursor.execute(insertItem, insert_item_params)
    # integrity error with nulls:
    # IntegrityError: ('23000', "[23000] [Microsoft][ODBC Driver 13 for SQL Server]
    # [SQL Server]Cannot insert the value NULL into column 'QuadrantID', table 
    # 'Group3-Final.dbo.tblItem'; column does not allow nulls. INSERT fails. (515) (SQLExecDirectW)")
    
    #cursor.execute(insertHouseGroup, insert_house_grp_params)
    # error with this one, below is error message:
    # Error: ('21000', '[21000] [Microsoft][ODBC Driver 13 for SQL Server][SQL Server]
    # Subquery returned more than 1 value. This is not permitted when the subquery 
    # follows =, !=, <, <= , >, >= or when the subquery is used as an expression. (512) (SQLExecDirectW)')    

    
    # DEBUG CODE:
    #print(email)
    #if pd.isnull(email):
    #   print("Oh no!")
    #print()
    
    #print(type(time))
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-128-b83aba4767db> in <module>
#     115     room_count = int(str(c.fetchall())[2:3])
#     116     if (room_count == 0):
# --> 117         cursor.execute(insertRoom, insert_room_params)
#     118
#     119     # error with this one, below is error message:
#
# Error: ('21000', '[21000] [Microsoft][ODBC Driver 13 for SQL Server][SQL Server]Subquery returned more than 1 value. This is not permitted when the subquery follows =, !=, <, <= , >, >= or when the subquery is used as an expression. (512) (SQLExecDirectW)')

# %%
# close db connection
cursor.commit()
cursor.close()
